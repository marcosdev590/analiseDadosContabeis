# %%
# Importa as bibliotecas necessárias para a conexão com o banco de dados ODBC

import pyodbc
import pandas as pd
import configparser
import warnings
from datetime import datetime

# Filtra o aviso procurando pelo texto exato da mensagem
warnings.filterwarnings(
    'ignore',
    message='pandas only supports SQLAlchemy.*' # Usamos a mensagem como filtro
)

print("Bibliotecas importadas e aviso configurado com sucesso!")
# Out:
# Bibliotecas importadas e aviso configurado com sucesso!

# %%
# Configura a função para solicitar e validar as datas de início e fim da consulta, além dos nomes dos arquivos de entrada e saída

def solicitar_data(prompt):
    while True:
        data_str = input(prompt)
        try:
            # Tenta converter a string para data no formato DD/MM/AAAA
            data_obj = datetime.strptime(data_str, '%d/%m/%Y')
            return data_obj
        except ValueError:
            print("❌ Formato de data inválido. Por favor, use o formato DD/MM/AAAA.")

print("Por favor, informe o período para a consulta de faturamento.")
data_inicial = solicitar_data("Digite a data inicial (DD/MM/AAAA): ")
data_final = solicitar_data("Digite a data final (DD/MM/AAAA):   ")

# Validação para garantir que a data final não seja anterior à inicial
while data_final < data_inicial:
    print("❌ A data final não pode ser anterior à data inicial. Por favor, insira as datas novamente.")
    data_inicial = solicitar_data("Digite a data inicial (DD/MM/AAAA): ")
    data_final = solicitar_data("Digite a data final (DD/MM/AAAA):   ")


# Formatando as datas para o formato que o arquivo SQL espera (AAAA-MM-DD)
DATA_INICIAL_SQL = data_inicial.strftime('%Y-%m-%d')
DATA_FINAL_SQL = data_final.strftime('%Y-%m-%d')

# Nomes dos arquivos de entrada e saída
ARQUIVO_CNPJS = 'cnpjs.txt'
ARQUIVO_SQL = 'faturamento.sql'
ARQUIVO_SAIDA_CSV = 'faturamento_final.csv'

print("\n✅ Datas definidas com sucesso!")
print(f"🗓️ Período de apuração: de {DATA_INICIAL_SQL} a {DATA_FINAL_SQL}")
# Out:
# Por favor, informe o período para a consulta de faturamento.
# Digite a data inicial (DD/MM/AAAA):  01012024
# ❌ Formato de data inválido. Por favor, use o formato DD/MM/AAAA.
# Digite a data inicial (DD/MM/AAAA):  01/01/2024
# Digite a data final (DD/MM/AAAA):    31/12/2024
# ✅ Datas definidas com sucesso!
# 🗓️ Período de apuração: de 2024-01-01 a 2024-12-31

# %%
# Configura e estabelece a conexão com o banco de dados ODBC

# Ler as configurações do arquivo config.ini
config = configparser.ConfigParser()
config.read('config.ini')

# Pegar as credenciais da seção [DATABASE]
dsn_name = config['DATABASE']['DSN']
user = config['DATABASE']['USER']
password = config['DATABASE']['PASSWORD']

# Montando a string de conexão
connection_string = f'DSN={dsn_name};UID={user};PWD={password}'

# Bloco try...except para tratar possíveis erros de conexão
try:
    # Tenta conectar ao banco de dados usando pyodbc
    conn = pyodbc.connect(connection_string, autocommit=True)
    
    # Se chegou até aqui, a conexão foi um sucesso!
    print("✅ Conexão com o banco de dados via pyodbc estabelecida com sucesso!")

except pyodbc.Error as ex:
    sqlstate = ex.args[0]
    print(f"❌ Erro na conexão com o banco de dados.")
    print(f"   Verifique se o nome do DSN ('{dsn_name}') e as credenciais estão corretos.")
    print(f"   Detalhe do erro: {ex}")
    conn = None # Garante que a variável conn não será usada se der erro
# Out:
# ✅ Conexão com o banco de dados via pyodbc estabelecida com sucesso!

# %%
# Carrega a query SQL e a lista de CNPJs

query_faturamento_base = ""
lista_cnpjs = []

if conn:
    try:
        with open(ARQUIVO_SQL, 'r', encoding='utf-8') as f:
            query_faturamento_base = f.read()
        print(f"✅ Arquivo SQL '{ARQUIVO_SQL}' carregado.")

        with open(ARQUIVO_CNPJS, 'r', encoding='utf-8') as f:
            # Remove espaços em branco e linhas vazias
            lista_cnpjs = [line.strip() for line in f if line.strip()]
        print(f"✅ Arquivo de CNPJs '{ARQUIVO_CNPJS}' carregado com {len(lista_cnpjs)} CNPJs.")

    except FileNotFoundError as e:
        print(f"❌ Erro: Arquivo não encontrado - {e}. Verifique se os nomes estão corretos.")
        conn = None # Impede a execução da próxima célula
# Out:
# ✅ Arquivo SQL 'faturamento.sql' carregado.
# ✅ Arquivo de CNPJs 'cnpjs.txt' carregado com 160 CNPJs.

# %%
# Consulta o faturamento

resultados = []

if conn and lista_cnpjs:
    print("\n--- Iniciando processamento do faturamento ---")
    total_cnpjs = len(lista_cnpjs)

    for i, cnpj in enumerate(lista_cnpjs):
        print(f"\n({i+1}/{total_cnpjs}) Processando CNPJ: {cnpj}")
        
        try:
            # 1. Encontrar o CODI_EMP e a RAZÃO SOCIAL a partir do CNPJ
            # A coluna CGCE_EMP geralmente armazena CNPJ/CPF e a NOME_EMP a razão social.
            query_codi_emp = f"SELECT codi_emp, nome_emp FROM bethadba.geempre WHERE cgce_emp = '{cnpj}'"
            df_empresa = pd.read_sql(query_codi_emp, conn)

            if df_empresa.empty:
                print(f"   ⚠️  Aviso: Nenhuma empresa encontrada para o CNPJ {cnpj}.")
                resultados.append({'CNPJ': cnpj, 'RAZAO_SOCIAL': 'NÃO ENCONTRADA', 'FATURAMENTO_TOTAL': 'NÃO ENCONTRADO'})
                continue

            codi_emp = df_empresa['codi_emp'].iloc[0]
            razao_social = df_empresa['nome_emp'].iloc[0]
            print(f"   > Empresa encontrada: {razao_social} (Cód: {codi_emp})")

            # 2. Preparar e executar a consulta de faturamento
            # Substituímos os parâmetros na sua query original
            query_modificada = query_faturamento_base.replace(':ALLISTAEMPRESAS', str(codi_emp))
            query_modificada = query_modificada.replace(':DATINI', f"'{DATA_INICIAL_SQL}'")
            query_modificada = query_modificada.replace(':DATFIN', f"'{DATA_FINAL_SQL}'")
            # Adicione outras substituições se houver mais parâmetros
            query_modificada = query_modificada.replace(":CIDAEMP", "'CIDADE'")
            query_modificada = query_modificada.replace(":CEPEEMP", "'CEP'")
            query_modificada = query_modificada.replace(":ENDEEMP", "'ENDERECO'")
            query_modificada = query_modificada.replace(":EXLUIR_CUSTO_AQUISICAO_VEICULO", "'N'")


            # 3. Agregamos a query complexa para obter um único valor de faturamento
            query_final_agregada = f"""
                SELECT
                    SUM(COALESCE(VSAI, 0) + COALESCE(VSER, 0) + COALESCE(VOUT, 0)) as FATURAMENTO_TOTAL
                FROM (
                    {query_modificada}
                ) AS subquery
            """

            df_faturamento = pd.read_sql(query_final_agregada, conn)

            if not df_faturamento.empty:
                faturamento_total = df_faturamento['FATURAMENTO_TOTAL'].iloc[0]
                faturamento_total = faturamento_total if pd.notna(faturamento_total) else 0
                print(f"   > Faturamento encontrado: R$ {faturamento_total:,.2f}")
                resultados.append({'CNPJ': cnpj, 'RAZAO_SOCIAL': razao_social, 'FATURAMENTO_TOTAL': faturamento_total})
            else:
                print("   > Nenhum dado de faturamento retornado para o período.")
                resultados.append({'CNPJ': cnpj, 'RAZAO_SOCIAL': razao_social, 'FATURAMENTO_TOTAL': 0.0})

        except Exception as e:
            print(f"   ❌ Erro ao processar o CNPJ {cnpj}: {e}")
            # Tenta adicionar a razão social mesmo em caso de erro, se já tiver sido encontrada
            razao_social_erro = razao_social if 'razao_social' in locals() else 'ERRO NA BUSCA'
            resultados.append({'CNPJ': cnpj, 'RAZAO_SOCIAL': razao_social_erro, 'FATURAMENTO_TOTAL': 'ERRO'})

    print("\n--- Processamento concluído ---")
# Out:
# --- Iniciando processamento do faturamento ---
#
# (1/160) Processando CNPJ: 52176809000172
#    > Empresa encontrada: 52.176.809 DOMINGOS JOSE MARIANO DOS SAN (Cód: 578)
#    > Faturamento encontrado: R$ 60,100.00
#
# (2/160) Processando CNPJ: 08898489000172
#    > Empresa encontrada: A P SANTOS (Cód: 571)
#    > Faturamento encontrado: R$ 390,224.68
#
# (3/160) Processando CNPJ: 00317929000149
#    > Empresa encontrada: ABAETE LINHAS AEREAS LTDA (Cód: 332)
#    > Faturamento encontrado: R$ 0.00
#
# (4/160) Processando CNPJ: 02758960000140
#    > Empresa encontrada: ACCIOLY ARAUJO E CIA LTDA. (Cód: 562)
#    > Faturamento encontrado: R$ 0.00
#
# (5/160) Processando CNPJ: 13243260000130
#    > Empresa encontrada: ADVOCACIA CAIO DRUSO (Cód: 224)
#    > Faturamento encontrado: R$ 3,636,680.54
#
# (6/160) Processando CNPJ: 28264218000172
#    > Empresa encontrada: AGI CONSTRUÇÕES E LOCAÇOES LTDA (Cód: 277)
#    > Faturamento encontrado: R$ 1,244,300.95
#
# (7/160) Processando CNPJ: 02085636000109
#    > Empresa encontrada: AGUIAR SERVICOS PSIQUIATRICOS  (Cód: 3)
#    > Faturamento encontrado: R$ 216,890.94
#
# (8/160) Processando CNPJ: 22416455000125
#    > Empresa encontrada: AKDK COMERCIO E EDITORA LTDA (Cód: 485)
#    > Faturamento encontrado: R$ 1,544,705.22
#
# (9/160) Processando CNPJ: 57441355000133
#    > Empresa encontrada: ALMEIDA & DELDUQUE HEALTHY WEALTH LTDA (Cód: 606)
#    > Faturamento encontrado: R$ 0.00
#
# (10/160) Processando CNPJ: 14864579000145
#    > Empresa encontrada: ALMEIDA CLINICA MEDICA LTDA (Cód: 480)
#    > Faturamento encontrado: R$ 9,517,815.00
#
# (11/160) Processando CNPJ: 39606204000106
#    > Empresa encontrada: ALTO DA BOA VISTA CONSTRUTORA, INCORPORA (Cód: 492)
#    > Faturamento encontrado: R$ 1,167,151.02
#
# (12/160) Processando CNPJ: 07588490000138
#    > Empresa encontrada: AMGOLA EMPREENDIMENTOS E PARTICIPACOES L (Cód: 474)
#    > Faturamento encontrado: R$ 0.00
#
# (13/160) Processando CNPJ: 15425231000114
#    > Empresa encontrada: ANA BURITY ARQUITETURA LTDA (Cód: 292)
#    > Faturamento encontrado: R$ 45,622.20
#
# (14/160) Processando CNPJ: 19157216000193
#    > Empresa encontrada: PATRIMONIAL TECNOLOGIA (Cód: 329)
#    > Faturamento encontrado: R$ 0.00
#
# (15/160) Processando CNPJ: 18877087000145
#    > Empresa encontrada: AR COND SERVICE LTDA (Cód: 577)
#    > Faturamento encontrado: R$ 1,862,147.54
#
# (16/160) Processando CNPJ: 31479304000107
#    > Empresa encontrada: ASSOCIACAO CIVIL DOS CONDOMINOS DO EDIFI (Cód: 583)
#    > Faturamento encontrado: R$ 0.00
#
# (17/160) Processando CNPJ: 57342218000141
#    > Empresa encontrada: ASSOCIACAO DA COMUNIDADE CHINESA NA BAHI (Cód: 605)
#    > Faturamento encontrado: R$ 0.00
#
# (18/160) Processando CNPJ: 06853860000154
#    > Empresa encontrada: ATEBA - ASSOC DOS ANALISTAS TECNICOS  (Cód: 92)
#    > Faturamento encontrado: R$ 0.00
#
# (19/160) Processando CNPJ: 14674451000119
#    > Empresa encontrada: ATA AEROTAXI ABAETE LTDA (Cód: 333)
#    > Faturamento encontrado: R$ 63,345,412.97
#
# (20/160) Processando CNPJ: 15130057000182
#    > Empresa encontrada: ATLANTA MANUTENCAO DE AERONAVES LTDA (Cód: 331)
#    > Faturamento encontrado: R$ 4,922,908.97
#
# (21/160) Processando CNPJ: 36489621000128
#    > Empresa encontrada: AZB CONSTRUTORA E INCORPORADORA DE EMPRE (Cód: 493)
#    > Faturamento encontrado: R$ 0.00
#
# (22/160) Processando CNPJ: 36489621000209
#    > Empresa encontrada: AZB CONSTRUTORA E INCORPORADORA DE EMPRE (Cód: 560)
#    > Faturamento encontrado: R$ 6,225,973.34
#
# (23/160) Processando CNPJ: 18317674000180
#    > Empresa encontrada: BETA - CONSTRUTORA, INCORPORADORA E IMOB (Cód: 563)
#    > Faturamento encontrado: R$ 0.00
#
# (24/160) Processando CNPJ: 58325997000130
#    > Empresa encontrada: BG CONSTRUTORA E INCORPORADORA DE EMPREE (Cód: 624)
#    > Faturamento encontrado: R$ 0.00
#
# (25/160) Processando CNPJ: 55065425000170
#    > Empresa encontrada: BIANCA DEGAUT SERVICOS VETERINARIOS LTDA (Cód: 595)
#    > Faturamento encontrado: R$ 36,815.10
#
# (26/160) Processando CNPJ: 29372361000140
#    > Empresa encontrada: BKCL GESTAO DE NEGOCIOS LTDA (Cód: 473)
#    > Faturamento encontrado: R$ 112,790.00
#
# (27/160) Processando CNPJ: 41317500000139
#    > Empresa encontrada: BRANDAO SOCCER ASSESSORIA ESPORTIVA LTDA (Cód: 472)
#    > Faturamento encontrado: R$ 0.00
#
# (28/160) Processando CNPJ: 29294033000173
#    > Empresa encontrada: BRAVIC MOTO PECAS E ACESSORIOS LTDA (Cód: 383)
#    > Faturamento encontrado: R$ 11,856,623.47
#
# (29/160) Processando CNPJ: 60649173000167
#    > Empresa encontrada: BTM PATRIMONIAL LTDA (Cód: 640)
#    > Faturamento encontrado: R$ 0.00
#
# (30/160) Processando CNPJ: 31383100000178
#    > Empresa encontrada: CAMPOS & LIMA – ADVOCACIA E CONSULTORIA (Cód: 369)
#    > Faturamento encontrado: R$ 226,259.80
#
# (31/160) Processando CNPJ: 04046508000181
#    > Empresa encontrada: CAPOSERV COMERCIO E SERVICOS DE CAPOTARI (Cód: 431)
#    > Faturamento encontrado: R$ 1,117,289.90
#
# (32/160) Processando CNPJ: 08512327000154
#    > Empresa encontrada: CATCO INVESTIMENTOS E PARTICIPACOES LTDA (Cód: 483)
#    > Faturamento encontrado: R$ 0.00
#
# (33/160) Processando CNPJ: 16273393000147
#    > Empresa encontrada: CELIA BRANDAO DA CRUZ COMERCIO VAREJISTA (Cód: 439)
#    > Faturamento encontrado: R$ 0.00
#
# (34/160) Processando CNPJ: 32913761000120
#    > Empresa encontrada: CENTRO DE FORMACAO DE CONDUTORES EQUILIB (Cód: 648)
#    > Faturamento encontrado: R$ 0.00
#
# (35/160) Processando CNPJ: 96758644000112
#    > Empresa encontrada: CENTRO DE FORMACAO DE CONDUTORES FANTAST (Cód: 420)
#    > Faturamento encontrado: R$ 1,167,792.19
#
# (36/160) Processando CNPJ: 04596843000153
#    > Empresa encontrada: CENTRO DE FORMACAO DE CONDUTORES TRANSIT (Cód: 461)
#    > Faturamento encontrado: R$ 324,736.16
#
# (37/160) Processando CNPJ: 42030791000142
#    > Empresa encontrada: CENTRO EDUCACIONAL IMBUI LTDA - ME (Cód: 121)
#    > Faturamento encontrado: R$ 463,792.18
#
# (38/160) Processando CNPJ: 56071606000172
#    > Empresa encontrada: CLEIDE COSTA DESIGN LTDA (Cód: 598)
#    > Faturamento encontrado: R$ 14,610.00
#
# (39/160) Processando CNPJ: 46368587000197
#    > Empresa encontrada: CLINICA CARVALHO DE QUEIROZ SERVICOS MED (Cód: 579)
#    > Faturamento encontrado: R$ 94,638.09
#
# (40/160) Processando CNPJ: 37676613000153
#    > Empresa encontrada: COMMPASS NUTRIÇÃO E MARKETING LTDA (Cód: 450)
#    > Faturamento encontrado: R$ 80,350.00
#
# (41/160) Processando CNPJ: 37115413000121
#    > Empresa encontrada: CONSTRUTECH FRANQUEADORA LTDA (Cód: 484)
#    > Faturamento encontrado: R$ 517,516.59
#
# (42/160) Processando CNPJ: 45410694000173
#    > Empresa encontrada: CUIDA E AMOR LTDA (Cód: 528)
#    > Faturamento encontrado: R$ 358,277.50
#
# (43/160) Processando CNPJ: 34686242000100
#    > Empresa encontrada: CUIDACOMAMOR APOIO E ASSISTENCIA A PACIE (Cód: 413)
#    > Faturamento encontrado: R$ 607,376.79
#
# (44/160) Processando CNPJ: 27599994000160
#    > Empresa encontrada: CUIDAMOR CUIDADO E APOIO ASSISTENCIA  (Cód: 375)
#    > Faturamento encontrado: R$ 0.00
#
# (45/160) Processando CNPJ: 09421425000149
#    > Empresa encontrada: D A PRODUÇÕES CIENTIFICAS LTDA EPP (Cód: 140)
#    > Faturamento encontrado: R$ 118,096.10
#
# (46/160) Processando CNPJ: 47347605000117
#    > Empresa encontrada: DBALL SPORTS ASSESSORIA ESPORTIVA LTDA (Cód: 527)
#    > Faturamento encontrado: R$ 0.00
#
# (47/160) Processando CNPJ: 06330818000159
#    > Empresa encontrada: DERALDO MOTTA NETO (Cód: 60)
#    > Faturamento encontrado: R$ 4,950.00
#
# (48/160) Processando CNPJ: 39455516000166
#    > Empresa encontrada: DIAGNOPREV ANALISES CLINICAS LTDA (Cód: 486)
#    > Faturamento encontrado: R$ 1,451,767.81
#
# (49/160) Processando CNPJ: 13015478000137
#    > Empresa encontrada: DIDIER PARTICIPAÇOES PATRIMONIAIS E EMPR (Cód: 218)
#    > Faturamento encontrado: R$ 750,000.00
#
# (50/160) Processando CNPJ: 05757350000110
#    > Empresa encontrada: DIDIER PRODUCAO CIENTIFICA LTDA. (Cód: 7)
#    > Faturamento encontrado: R$ 599,019.84
#
# (51/160) Processando CNPJ: 27938267000180
#    > Empresa encontrada: DLJ ENGENHARIA LTDA (Cód: 590)
#    > Faturamento encontrado: R$ 2,525,297.87
#
# (52/160) Processando CNPJ: 37942966000158
#    > Empresa encontrada: DMA CONSTRUTORA, INCORPORADORA E IMOBILI (Cód: 451)
#    > Faturamento encontrado: R$ 0.00
#
# (53/160) Processando CNPJ: 08594998000101
#    > Empresa encontrada: DS PARTICIPAÇÕES LTDA (Cód: 103)
#    > Faturamento encontrado: R$ 110,010.00
#
# (54/160) Processando CNPJ: 48509381000165
#    > Empresa encontrada: EH TECNOLOGIA EMPRESARIAL LTDA (Cód: 540)
#    > Faturamento encontrado: R$ 0.00
#
# (55/160) Processando CNPJ: 50599247000144
#    > Empresa encontrada: EMEG MEDICINA INTEGRAL LTDA (Cód: 553)
#    > Faturamento encontrado: R$ 569,491.06
#
# (56/160) Processando CNPJ: 08418899000179
#    > Empresa encontrada: EMIL EMPREENDIMENTOS IMOBILIARIOS LTDA (Cód: 567)
#    > Faturamento encontrado: R$ 0.00
#
# (57/160) Processando CNPJ: 20589499000121
#    > Empresa encontrada: ESCOLA CRECHE OLIVEIRA LTDA (Cód: 521)
#    > Faturamento encontrado: R$ 410,748.63
#
# (58/160) Processando CNPJ: 20589499000202
#    > Empresa encontrada: ESCOLA CRECHE OLIVEIRA LTDA (Cód: 525)
#    > Faturamento encontrado: R$ 206,536.67
#
# (59/160) Processando CNPJ: 16518452000108
#    > Empresa encontrada: EUROPA SERVICOS DE COBRANCA LTDA (Cód: 389)
#    > Faturamento encontrado: R$ 0.00
#
# (60/160) Processando CNPJ: 15125214000161
#    > Empresa encontrada: FRANCISCO F.  AMARAL FILHO (Cód: 358)
#    > Faturamento encontrado: R$ 0.00
#
# (61/160) Processando CNPJ: 60408033000105
#    > Empresa encontrada: F&F - FALEIRO E FERREIRA ADMINISTRACAO E (Cód: 638)
#    > Faturamento encontrado: R$ 0.00
#
# (62/160) Processando CNPJ: 10730841000108
#    > Empresa encontrada: FIGUEIREDO FIGUEIREDO CONSULTORIA E SEVI (Cód: 291)
#    > Faturamento encontrado: R$ 180,398.54
#
# (63/160) Processando CNPJ: 47270498000176
#    > Empresa encontrada: G MAKER LTDA (Cód: 526)
#    > Faturamento encontrado: R$ 55,553.40
#
# (64/160) Processando CNPJ: 58120702000199
#    > Empresa encontrada: GATO PARTICIPACOES IMOBILIARIAS LTDA (Cód: 620)
#    > Faturamento encontrado: R$ 0.00
#
# (65/160) Processando CNPJ: 27179477000132
#    > Empresa encontrada: GOMES MARTINS COMERCIO E SERVICO LTDA (Cód: 316)
#    > Faturamento encontrado: R$ 456,230.08
#
# (66/160) Processando CNPJ: 07533211000139
#    > Empresa encontrada: GSCC PAISAGISMO E JARDINAGEM LTDA (Cód: 83)
#    > Faturamento encontrado: R$ 659,526.09
#
# (67/160) Processando CNPJ: 45615233000137
#    > Empresa encontrada: HAMDAN SERVICOS DE APOIO ADMINISTRATIVO  (Cód: 511)
#    > Faturamento encontrado: R$ 0.00
#
# (68/160) Processando CNPJ: 20643665000120
#    > Empresa encontrada: IGOR BRANDAO DA CRUZ EIRELI (Cód: 438)
#    > Faturamento encontrado: R$ 2,347,294.44
#
# (69/160) Processando CNPJ: 09238540000182
#    > Empresa encontrada: IGREJA BATISTA AVIVAMENTO MUNDIAL (Cód: 529)
#    > Faturamento encontrado: R$ 0.00
#
# (70/160) Processando CNPJ: 61703947000153
#    > Empresa encontrada: INVESTMED SOLUCOES FINANCEIRAS LTDA (Cód: 647)
#    > Faturamento encontrado: R$ 0.00
#
# (71/160) Processando CNPJ: 47812570000140
#    > Empresa encontrada: J SAM TRANSPORTES LTDA (Cód: 533)
#    > Faturamento encontrado: R$ 4,299,595.33
#
# (72/160) Processando CNPJ: 01327697000172
#    > Empresa encontrada: J. FERNANDES LANCHERIA E DRINKS LTDA-ME (Cód: 310)
#    > Faturamento encontrado: R$ 311,275.15
#
# (73/160) Processando CNPJ: 14805185000116
#    > Empresa encontrada: JJ MARINHO LOCACOES DE MAQUINAS LTDA (Cód: 341)
#    > Faturamento encontrado: R$ 0.00
#
# (74/160) Processando CNPJ: 00625183000130
#    > Empresa encontrada: JTM COMPUTADORES LTDA (Cód: 20)
#    > Faturamento encontrado: R$ 332,948.97
#
# (75/160) Processando CNPJ: 34793061000175
#    > Empresa encontrada: JUAREZ TEIXEIRA SEGUNDO (Cód: 515)
#    > Faturamento encontrado: R$ 613,723.40
#
# (76/160) Processando CNPJ: 42976224000183
#    > Empresa encontrada: KAICO PARTICIPACOES EIRELI (Cód: 497)
#    > Faturamento encontrado: R$ 0.00
#
# (77/160) Processando CNPJ: 28997640000137
#    > Empresa encontrada: LAGO & SARNO - ADVOCACIA E CONSULTORIA (Cód: 334)
#    > Faturamento encontrado: R$ 185,547.52
#
# (78/160) Processando CNPJ: 11888678000179
#    > Empresa encontrada: LAGO SARNO PRODUCAO CIENTIFICA LTDA  (Cód: 212)
#    > Faturamento encontrado: R$ 226,567.08
#
# (79/160) Processando CNPJ: 54874761000100
#    > Empresa encontrada: LDJ SERVICOS DE CONSTRUCAO CIVIL LTDA (Cód: 594)
#    > Faturamento encontrado: R$ 0.00
#
# (80/160) Processando CNPJ: 33394903000153
#    > Empresa encontrada: LELY PARTICIPACOES LTDA (Cód: 401)
#    > Faturamento encontrado: R$ 354,598.79
#
# (81/160) Processando CNPJ: 49848540000119
#    > Empresa encontrada: LF COMERCIO E LOCACAO DE VESTUARIOS E AC (Cód: 626)
#    > Faturamento encontrado: R$ 0.00
#
# (82/160) Processando CNPJ: 31954593000159
#    > Empresa encontrada: LIAR LOCACAO DE MAQUINAS E EQUIPAMENTOS (Cód: 381)
#    > Faturamento encontrado: R$ 0.00
#
# (83/160) Processando CNPJ: 51305486000107
#    > Empresa encontrada: LIVIA GALVAO SERVICOS MEDICOS LTDA (Cód: 559)
#    > Faturamento encontrado: R$ 48,334.84
#
# (84/160) Processando CNPJ: 10798351000143
#    > Empresa encontrada: LM MONTAGENS E EVENTOS LTDA-ME (Cód: 189)
#    > Faturamento encontrado: R$ 0.00
#
# (85/160) Processando CNPJ: 50487410000187
#    > Empresa encontrada: LOGO GERENCIA DE COBRANCAS LTDA (Cód: 552)
#    > Faturamento encontrado: R$ 1,115,285.75
#
# (86/160) Processando CNPJ: 23086505000116
#    > Empresa encontrada: LOGO GESTAO E INVESTIMENTOS IMOBILIARIOS (Cód: 319)
#    > Faturamento encontrado: R$ 1,728,772.60
#
# (87/160) Processando CNPJ: 10230995000130
#    > Empresa encontrada: LOGOSERV GESTAO DE PESSOAS LTDA (Cód: 168)
#    > Faturamento encontrado: R$ 2,163,093.18
#
# (88/160) Processando CNPJ: 01041880000107
#    > Empresa encontrada: LOGOSERV RECURSOS HUMANOS E SERVIÇO LTDA (Cód: 162)
#    > Faturamento encontrado: R$ 28,720,169.92
#
# (89/160) Processando CNPJ: 13841164000193
#    > Empresa encontrada: LOSERVICE SERVICOS DE COBRANCA LTDA (Cód: 220)
#    > Faturamento encontrado: R$ 10,284.26
#
# (90/160) Processando CNPJ: 49593665000145
#    > Empresa encontrada: LTT PATRIMONIAL LTDA (Cód: 546)
#    > Faturamento encontrado: R$ 0.00
#
# (91/160) Processando CNPJ: 44688937000177
#    > Empresa encontrada: LUCIANA MENEZES MARQUES 02418004716 (Cód: 661)
#    > Faturamento encontrado: R$ 0.00
#
# (92/160) Processando CNPJ: 15622702000184
#    > Empresa encontrada: LUCIANO FIGUEIREDO - ADVOCACIA E CONSULT (Cód: 299)
#    > Faturamento encontrado: R$ 382,172.13
#
# (93/160) Processando CNPJ: 32298165000188
#    > Empresa encontrada: M&L TRANSPORTADORA LTDA (Cód: 388)
#    > Faturamento encontrado: R$ 0.00
#
# (94/160) Processando CNPJ: 24681478000192
#    > Empresa encontrada: MACHADO BISNETO SOCIEDADE INDIVIDUAL DE  (Cód: 349)
#    > Faturamento encontrado: R$ 756,487.19
#
# (95/160) Processando CNPJ: 40092954000196
#    > Empresa encontrada: MAP - MEDICINA DE ALTA PERFORMANCE LTDA (Cód: 478)
#    > Faturamento encontrado: R$ 10,249,502.51
#
# (96/160) Processando CNPJ: 45075482000187
#    > Empresa encontrada: MARCASTELLO TREINAMENTO E PROMOCAO DE VE (Cód: 545)
#    > Faturamento encontrado: R$ 326,761.59
#
# (97/160) Processando CNPJ: 31382516000171
#    > Empresa encontrada: MARIANA PAZ PSICOLOGIA INFANTIL EIRELI (Cód: 415)
#    > Faturamento encontrado: R$ 742,711.00
#
# (98/160) Processando CNPJ: 53752187000146
#    > Empresa encontrada: MB COMERCIO DE MOVEIS LTDA (Cód: 587)
#    > Faturamento encontrado: R$ 2,960,297.34
#
# (99/160) Processando CNPJ: 16081507000157
#    > Empresa encontrada: MECANICA NOGUEIRA LTDA-ME (Cód: 75)
#    > Faturamento encontrado: R$ 771,019.50
#
# (100/160) Processando CNPJ: 00114608000147
#    > Empresa encontrada: MEDCENTER ENDOBESI SERVICOS MEDICOS LTDA (Cód: 584)
#    > Faturamento encontrado: R$ 943,129.42
#
# (101/160) Processando CNPJ: 18661855000129
#    > Empresa encontrada: MH3 ENGENHARIA LTDA EPP (Cód: 280)
#    > Faturamento encontrado: R$ 243,333.34
#
# (102/160) Processando CNPJ: 14708762000151
#    > Empresa encontrada: MMMA INSTITUIÇÃO DE ENSINO EIRELI (Cód: 122)
#    > Faturamento encontrado: R$ 567,751.77
#
# (103/160) Processando CNPJ: 23239224000156
#    > Empresa encontrada: MO COMERCIO DE MOVEIS MODULADOS LTDA (Cód: 445)
#    > Faturamento encontrado: R$ 3,203,395.88
#
# (104/160) Processando CNPJ: 28038643000143
#    > Empresa encontrada: MOBI TRADING REPRESENTACAO E COMERCIO EI (Cód: 532)
#    > Faturamento encontrado: R$ 100,000.00
#
# (105/160) Processando CNPJ: 10979504000159
#    > Empresa encontrada: MR INTERGRUAS LOCACAO DE EQUIPAMENTOS LT (Cód: 191)
#    > Faturamento encontrado: R$ 180,354.50
#
# (106/160) Processando CNPJ: 25230500000140
#    > Empresa encontrada: MT ADMINISTRACAO DE BENS PROPRIOS LTDA (Cód: 338)
#    > Faturamento encontrado: R$ 899,660.14
#
# (107/160) Processando CNPJ: 38334794000100
#    > Empresa encontrada: MVH LTDA (Cód: 489)
#    > Faturamento encontrado: R$ 1,380,861.43
#
# (108/160) Processando CNPJ: 15192986000116
#    > Empresa encontrada: NÁPOLI PRODUÇÕES CIENTIFICAS LTDA EPP (Cód: 238)
#    > Faturamento encontrado: R$ 57,690.68
#
# (109/160) Processando CNPJ: 11899462000109
#    > Empresa encontrada: NAS TRANSPORTES E LOGISTICA LTDA (Cód: 211)
#    > Faturamento encontrado: R$ 0.00
#
# (110/160) Processando CNPJ: 51502397000150
#    > Empresa encontrada: NUTRI TOP NUTRICAO E GESTAO ADMINISTRATI (Cód: 561)
#    > Faturamento encontrado: R$ 126,231.90
#
# (111/160) Processando CNPJ: 08009190000110
#    > Empresa encontrada: OF COMERCIO DE MOVEIS LTDA (Cód: 259)
#    > Faturamento encontrado: R$ 3,001,792.43
#
# (112/160) Processando CNPJ: 15151269000146
#    > Empresa encontrada: OLEOS DE PALMA S A AGRO INDUSTRIAL (Cód: 466)
#    > Faturamento encontrado: R$ 0.00
#
# (113/160) Processando CNPJ: 41494890000112
#    > Empresa encontrada: OLIVEIRA & CAMPOS ADVOCACIA (Cód: 475)
#    > Faturamento encontrado: R$ 247,773.90
#
# (114/160) Processando CNPJ: 05771842000160
#    > Empresa encontrada: ONIX ASSESSORIA CONTABIL S/S - EPP (Cód: 65)
#    > Faturamento encontrado: R$ 874,190.64
#
# (115/160) Processando CNPJ: 18430969000168
#    > Empresa encontrada: PAMPLONA PRODUCOES CIENTIFICA LTDA EPP (Cód: 271)
#    > Faturamento encontrado: R$ 267,669.52
#
# (116/160) Processando CNPJ: 15106552000156
#    > Empresa encontrada: PASSAGEM AGROPECUARIA LTDA (Cód: 565)
#    > Faturamento encontrado: R$ 3,002,529.57
#
# (117/160) Processando CNPJ: 38450878000100
#    > Empresa encontrada: PATRIMONIAL GABRIEL ALMEIDA PARTICIPACOE (Cód: 477)
#    > Faturamento encontrado: R$ 0.00
#
# (118/160) Processando CNPJ: 52674965000163
#    > Empresa encontrada: PATRIMONIAL TECNOLOGIA E COMERCIO LTDA (Cód: 575)
#    > Faturamento encontrado: R$ 571,899.44
#
# (119/160) Processando CNPJ: 49614465000121
#    > Empresa encontrada: PATRIMONIAL TECNOLOGIA E SOLUCOES PREDIA (Cód: 547)
#    > Faturamento encontrado: R$ 2,023,248.75
#
# (120/160) Processando CNPJ: 59347451000142
#    > Empresa encontrada: PERLA BARBOZA SERVICOS MEDICOS LTDA (Cód: 662)
#    > Faturamento encontrado: R$ 0.00
#
# (121/160) Processando CNPJ: 36442318000170
#    > Empresa encontrada: POUSADA BOUGAINVILLE ITAPUA LTDA (Cód: 437)
#    > Faturamento encontrado: R$ 277,644.38
#
# (122/160) Processando CNPJ: 57067174000199
#    > Empresa encontrada: RAIZA ALVES PEREIRA SERVICOS MEDICOS LTD (Cód: 602)
#    > Faturamento encontrado: R$ 77,494.76
#
# (123/160) Processando CNPJ: 28040811000135
#    > Empresa encontrada: RB COMERCIO DE SEMIJOIAS LTDA (Cód: 542)
#    > Faturamento encontrado: R$ 718,457.34
#
# (124/160) Processando CNPJ: 34537351000158
#    > Empresa encontrada: RCGAT BRASIL CONSULTORIA EIRELI (Cód: 409)
#    > Faturamento encontrado: R$ 147,300.00
#
# (125/160) Processando CNPJ: 13590182000140
#    > Empresa encontrada: REFRIC BAHIA  (Cód: 250)
#    > Faturamento encontrado: R$ 3,372,217.46
#
# (126/160) Processando CNPJ: 40261945000181
#    > Empresa encontrada: REFRIGERACAO GOMES COMERCIO DE PECAS LTD (Cód: 471)
#    > Faturamento encontrado: R$ 1,036,075.99
#
# (127/160) Processando CNPJ: 34432828000130
#    > Empresa encontrada: REZUT GESTAO CONDOMINIAL LTDA (Cód: 406)
#    > Faturamento encontrado: R$ 674,091.96
#
# (128/160) Processando CNPJ: 08611549000124
#    > Empresa encontrada: RML FUNDACOES LTDA (Cód: 106)
#    > Faturamento encontrado: R$ 2,129,435.60
#
# (129/160) Processando CNPJ: 46139356000101
#    > Empresa encontrada: ROBERTO FIGUEIREDO SERVICOS EDUCACIONAIS (Cód: 513)
#    > Faturamento encontrado: R$ 888,529.44
#
# (130/160) Processando CNPJ: 44581337000105
#    > Empresa encontrada: ROXINOL TRANSPORTES LTDA (Cód: 507)
#    > Faturamento encontrado: R$ 169,787.89
#
# (131/160) Processando CNPJ: 13124107000193
#    > Empresa encontrada: SAO LAZARO PARTICIPAÇÕES PATRIMONIAIS E  (Cód: 247)
#    > Faturamento encontrado: R$ 785,718.00
#
# (132/160) Processando CNPJ: 11815216000121
#    > Empresa encontrada: SD SAN DIEGO EMBALAGENS EIRELI (Cód: 441)
#    > Faturamento encontrado: R$ 8,589,154.57
#
# (133/160) Processando CNPJ: 11815216000202
#    > Empresa encontrada: SD SAN DIEGO EMBALAGENS EIRELI (Cód: 440)
#    > Faturamento encontrado: R$ 1,189,430.57
#
# (134/160) Processando CNPJ: 34341867000122
#    > Empresa encontrada: SD STOC COMERCIO VAREJISTA DE ARTIGOS DE (Cód: 294)
#    > Faturamento encontrado: R$ 267,671.44
#
# (135/160) Processando CNPJ: 12341197000101
#    > Empresa encontrada: TOP CONSULTORIA EMPRESARIAL LTDA (Cód: 459)
#    > Faturamento encontrado: R$ 0.00
#
# (136/160) Processando CNPJ: 41654001000137
#    > Empresa encontrada: SILVA AMADO PRODUCAO CIENTIFICA LTDA (Cód: 482)
#    > Faturamento encontrado: R$ 1,913,815.08
#
# (137/160) Processando CNPJ: 13549449000155
#    > Empresa encontrada: SINDICATO DAS INDUSTRIAS DE PRODUTOS QUI (Cód: 282)
#    > Faturamento encontrado: R$ 17,114.65
#
# (138/160) Processando CNPJ: 42175802000182
#    > Empresa encontrada: SMPSI SOC MED PARA PROMOCAO DA SAUDE INT (Cód: 45)
#    > Faturamento encontrado: R$ 734,026.75
#
# (139/160) Processando CNPJ: 43772767000222
#    > Empresa encontrada: SOHAPP INTELIGENCIA EM VAREJO LTDA (Cód: 610)
#    > Faturamento encontrado: R$ 0.00
#
# (140/160) Processando CNPJ: 35000853000108
#    > Empresa encontrada: SOLAR DO CANDEAL INDUSTRIA E COMERCIO DE (Cód: 418)
#    > Faturamento encontrado: R$ 50,700.00
#
# (141/160) Processando CNPJ: 36646165000182
#    > Empresa encontrada: SONATA PARTICIPACOES LTDA (Cód: 531)
#    > Faturamento encontrado: R$ 0.00
#
# (142/160) Processando CNPJ: 37899418000192
#    > Empresa encontrada: SPA INTIMO LTDA (Cód: 518)
#    > Faturamento encontrado: R$ 918,498.00
#
# (143/160) Processando CNPJ: 29163322000133
#    > Empresa encontrada: SRC COMERCIO VAREJISTA DE SEMI JOIAS LTD (Cód: 159)
#    > Faturamento encontrado: R$ 261,405.78
#
# (144/160) Processando CNPJ: 01379883000155
#    > Empresa encontrada: TC EMPREENDIMENTOS LTDA (Cód: 312)
#    > Faturamento encontrado: R$ 2,426,004.11
#
# (145/160) Processando CNPJ: 11996371000191
#    > Empresa encontrada: TRANSCICLA COMERCIO E RECICLAGEM DE PLAS (Cód: 201)
#    > Faturamento encontrado: R$ 669,048.15
#
# (146/160) Processando CNPJ: 29303121000194
#    > Empresa encontrada: TRANSPORTADORA BETA LTDA (Cód: 568)
#    > Faturamento encontrado: R$ 0.00
#
# (147/160) Processando CNPJ: 04124490000199
#    > Empresa encontrada: TRANSPORTADORA LEAO LTDA. (Cód: 36)
#    > Faturamento encontrado: R$ 0.00
#
# (148/160) Processando CNPJ: 11810069000105
#    > Empresa encontrada: TRINDADE AMADO PRODUCAO CIENTIFICA LTDA  (Cód: 198)
#    > Faturamento encontrado: R$ 2,435,708.16
#
# (149/160) Processando CNPJ: 58064794000137
#    > Empresa encontrada: TROPICAL BAHIA INDUSTRIA E COMERCIO DE R (Cód: 618)
#    > Faturamento encontrado: R$ 134,311.60
#
# (150/160) Processando CNPJ: 58064794000218
#    > Empresa encontrada: TROPICAL BAHIA INDUSTRIA E COMERCIO DE R (Cód: 635)
#    > Faturamento encontrado: R$ 0.00
#
# (151/160) Processando CNPJ: 58064794000307
#    > Empresa encontrada: TROPICAL BAHIA INDUSTRIA E COMERCIO DE R (Cód: 636)
#    > Faturamento encontrado: R$ 0.00
#
# (152/160) Processando CNPJ: 57286735000140
#    > Empresa encontrada: TS TOP SERVICOS DE REFRIGERACAO LTDA (Cód: 604)
#    > Faturamento encontrado: R$ 45,518.00
#
# (153/160) Processando CNPJ: 13664375000106
#    > Empresa encontrada: UN REVE NOIVAS E FESTAS LTDA (Cód: 625)
#    > Faturamento encontrado: R$ 0.00
#
# (154/160) Processando CNPJ: 35746614000100
#    > Empresa encontrada: UNICO CONSTRUTORA, INCORPORADORA E IMOBI (Cód: 456)
#    > Faturamento encontrado: R$ 0.00
#
# (155/160) Processando CNPJ: 35746614000282
#    > Empresa encontrada: UNICO CONSTRUTORA, INCORPORADORA E IMOBI (Cód: 537)
#    > Faturamento encontrado: R$ 6,953,228.48
#
# (156/160) Processando CNPJ: 57558833000190
#    > Empresa encontrada: VALE BENEFICIOS SERVICOS LTDA (Cód: 607)
#    > Faturamento encontrado: R$ 0.00
#
# (157/160) Processando CNPJ: 34279927000124
#    > Empresa encontrada: VAPEÇAS COMÉRCIO DE PEÇAS LTDA-ME (Cód: 35)
#    > Faturamento encontrado: R$ 689,134.26
#
# (158/160) Processando CNPJ: 28746285000123
#    > Empresa encontrada: VIANA E CALDAS ADVOCACIA (Cód: 494)
#    > Faturamento encontrado: R$ 127,748.52
#
# (159/160) Processando CNPJ: 13993421000102
#    > Empresa encontrada: VILLE DESIGN INDUSTRIA COMERCIO E SERVIC (Cód: 432)
#    > Faturamento encontrado: R$ 943,051.18
#
# (160/160) Processando CNPJ: 09200349000141
#    > Empresa encontrada: VINTE E UM DE JULHO EMPREENDIMENTOS LTDA (Cód: 125)
#    > Faturamento encontrado: R$ 1,368,365.12
#
# --- Processamento concluído ---

# %%
# Gera o arquivo de saída ao transformar a lista de resultados num DataFrame e salvá-lo como CSV

if resultados:
    print("\n--- Gerando arquivo de resultado ---")
    df_resultados = pd.DataFrame(resultados)
    
    def formatar_moeda_br(valor):
        """Formata um número para o padrão de moeda brasileiro (ex: 1.234,56)."""
        if not isinstance(valor, (int, float)):
            return valor # Retorna strings como 'ERRO' ou 'NÃO ENCONTRADO' como estão.
        
        # Formata o número (ex: 1234.56 -> "1,234.56")
        valor_formatado_en = f"{valor:,.2f}"
        # Converte para o padrão brasileiro (ex: "1,234.56" -> "1.234,56")
        valor_formatado_br = valor_formatado_en.replace(",", "X").replace(".", ",").replace("X", ".")
        return valor_formatado_br

    # Formatação para melhor visualização no CSV
    if 'FATURAMENTO_TOTAL' in df_resultados.columns:
        # Converte a coluna para tipo numérico, tratando erros (textos viram NaN)
        df_resultados['FATURAMENTO_TOTAL_NUM'] = pd.to_numeric(df_resultados['FATURAMENTO_TOTAL'], errors='coerce')
        
        # Aplica a função de formatação na coluna numérica
        df_resultados['FATURAMENTO_TOTAL_FORMATADO'] = df_resultados['FATURAMENTO_TOTAL_NUM'].apply(formatar_moeda_br)
        
        # Onde a formatação resultou em 'None' (para os erros), preenche com o valor original.
        df_resultados['FATURAMENTO_TOTAL_FORMATADO'] = df_resultados['FATURAMENTO_TOTAL_FORMATADO'].fillna(df_resultados['FATURAMENTO_TOTAL'])

    try:
        # Seleciona as colunas finais para o CSV, na ordem desejada
        df_final_para_csv = df_resultados[['CNPJ', 'RAZAO_SOCIAL', 'FATURAMENTO_TOTAL_FORMATADO']]

        df_final_para_csv.to_csv(
            ARQUIVO_SAIDA_CSV, 
            index=False, 
            sep=';', # Usando ';' para abrir corretamente no Excel brasileiro
            encoding='utf-8-sig',
            header=['CNPJ', 'RAZAO_SOCIAL', 'FATURAMENTO_TOTAL'] # Renomeando as colunas no arquivo final
        )
        print(f"✅ Resultados salvos com sucesso em '{ARQUIVO_SAIDA_CSV}'!")

        print("\nPré-visualização dos resultados:")
        try:
            display(df_final_para_csv)
        except NameError:
            print(df_final_para_csv.to_string())

    except Exception as e:
        print(f"❌ Erro ao salvar o arquivo CSV: {e}")

# Fechar a conexão ao final de tudo
if conn:
    conn.close()
    print("\nConexão com o banco de dados fechada.")
# Out:
# --- Gerando arquivo de resultado ---
# ✅ Resultados salvos com sucesso em 'faturamento_final.csv'!
#
# Pré-visualização dos resultados:
#                CNPJ                              RAZAO_SOCIAL  \
# 0    52176809000172  52.176.809 DOMINGOS JOSE MARIANO DOS SAN
# 1    08898489000172                                A P SANTOS
# 2    00317929000149                 ABAETE LINHAS AEREAS LTDA
# 3    02758960000140                ACCIOLY ARAUJO E CIA LTDA.
# 4    13243260000130                      ADVOCACIA CAIO DRUSO
# ..              ...                                       ...
# 155  57558833000190             VALE BENEFICIOS SERVICOS LTDA
# 156  34279927000124         VAPEÇAS COMÉRCIO DE PEÇAS LTDA-ME
# 157  28746285000123                  VIANA E CALDAS ADVOCACIA
# 158  13993421000102  VILLE DESIGN INDUSTRIA COMERCIO E SERVIC
# 159  09200349000141  VINTE E UM DE JULHO EMPREENDIMENTOS LTDA
#
#     FATURAMENTO_TOTAL_FORMATADO
# 0                     60.100,00
# 1                    390.224,68
# 2                          0,00
# 3                          0,00
# 4                  3.636.680,54
# ..                          ...
# 155                        0,00
# 156                  689.134,26
# 157                  127.748,52
# 158                  943.051,18
# 159                1.368.365,12
#
# [160 rows x 3 columns]
# Conexão com o banco de dados fechada.
